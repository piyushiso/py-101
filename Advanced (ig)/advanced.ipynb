# %% [markdown]
# # **Advance Concepts**
#
# Database, App, Website & Stuffs...

# %% [markdown]
# ## **Database using SQLlite**

# %%
import sqlite3

con = sqlite3.connect("test.db")
cursor = con.cursor()

cursor.execute("CREATE TABLE student (id INTEGER, name TEXT)")
cursor.execute("INSERT INTO students VALUES (1, 'Ram')")

con.commit()

cursor.execute("SELECT * FROM students")
print(cursor.fetchall())

con.close()
