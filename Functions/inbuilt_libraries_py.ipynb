# %% [markdown]
# # **Inbuilt Functions**

# %%
from collections import Counter

students = [
    {"roll": 1, "name": "ABHISHEK KESHARI", "marks": "Abs"},
    {"roll": 2, "name": "ABISKAR GHIMIRE", "marks": 8},
    {"roll": 3, "name": "ANJALI PARIYAR", "marks": 8},
    {"roll": 4, "name": "ANSHU KUNWAR", "marks": 55},
    {"roll": 5, "name": "ANUP POKHAREL", "marks": 39},
    {"roll": 6, "name": "BISHESH SHRESTHA", "marks": 4},
    {"roll": 7, "name": "JESHIKA PAUDEL", "marks": 25},
    {"roll": 8, "name": "KRITIKA DHODARI", "marks": 32},
    {"roll": 9, "name": "KUMARI PINKU SAH", "marks": 40},
    {"roll": 10, "name": "KURESH TIMALSINA", "marks": 31},
    {"roll": 11, "name": "LINA KARN", "marks": "Abs"},
    {"roll": 12, "name": "MUSKAN DAS", "marks": 10},
    {"roll": 13, "name": "MUSKAN TAMANG", "marks": 1},
    {"roll": 14, "name": "NISCHAL MASKEY", "marks": 12},
    {"roll": 15, "name": "NOEL KARKI", "marks": "Abs"},
    {"roll": 16, "name": "PRASHANT PAUDEL", "marks": 22},
    {"roll": 17, "name": "PUJA GURUARCHARYA", "marks": 0},
    {"roll": 18, "name": "RACHANA NEPAL", "marks": 10},
    {"roll": 19, "name": "RAHUL DAS BANIYA", "marks": 15},
    {"roll": 20, "name": "RICKY GARG", "marks": "Abs"},
    {"roll": 21, "name": "RISIKA DULAL", "marks": 20},
    {"roll": 22, "name": "RIYA ADHIKARI", "marks": 11},
    {"roll": 23, "name": "SANDHYA GUPTA", "marks": 8},
    {"roll": 24, "name": "SANZEET KUMAR DAS", "marks": 38},
    {"roll": 25, "name": "SNEHA KUNWAR", "marks": 31},
    {"roll": 26, "name": "SURYAKANT SAH", "marks": 20}
]

count = Counter()
# Out:
# Abs
# 8
# 8
# 55
# 39
# 4
# 25
# 32
# 40
# 31
# Abs
# 10
# 1
# 12
# Abs
# 22
# 0
# 10
# 15
# Abs
# 20
# 11
# 8
# 38
# 31
# 20
