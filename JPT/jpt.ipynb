# %%
print((3 ** 3)/(3**2))
# Out:
# 3.0

# %%
people = [
    {"name": "Anjali", "gender": "Female", "age": 28},
    {"name": "Sita", "gender": "Female", "age": 35},
    {"name": "Ram", "gender": "Male", "age": 40},
    {"name": "Gita", "gender": "Female", "age": 45},
    {"name": "Hari", "gender": "Male", "age": 25}
]

print(list(filter(lambda x: x['gender'] == 'Female' and x['age'] >= 30, people)))
# Out:
# [{'name': 'Sita', 'gender': 'Female', 'age': 35}, {'name': 'Gita', 'gender': 'Female', 'age': 45}]
